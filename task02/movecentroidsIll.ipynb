# %%
import numpy as np

# %%
x = [[1,3], [2, 3], [3, 4]]

# %%
cluster_group = np.array([1, 0, 0, 1, 0])

# %%
np.unique(cluster_group)
# Out:
# array([0, 1])

# %%
for types in np.unique(cluster_group):
    print(types)
# Out:
# 0
# 1

# %%
for i in range(3):
    x[cluster_group == i].mean(axis = 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 for i in range(3):
# ----> 2     x[cluster_group == i].mean(axis = 0)
#
# TypeError: only integer scalar arrays can be converted to a scalar index
